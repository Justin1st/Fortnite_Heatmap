# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
# %matplotlib inline

df = pd.read_csv("rawData.csv")

# %%
#Plot killcount and position
df_scatter = df.iloc[:, 1:3]
x = df_scatter["Position"]
y = df_scatter["KillCount"]

plt.scatter(x,y)
plt.ylabel("KillCount")
plt.xlabel("Placement")
plt.show()

# %%
#Select Location and KillCount 
avg_kills = df.iloc[:,0:2]

#Average number of kills per location
group_kill = avg_kills.groupby('Location').agg('mean')


plot = group_kill.plot(kind = 'bar', color = 'green')

# %%
#Average position per drop location
avg_pos = df.iloc[:,[0,2]]
avg_pos

group_pos = avg_pos.groupby('Location').agg('mean')

plot = group_pos.plot(kind = 'kde', color = 'red')

# %%
#Seperate the hand entered and trusted data from the data collected online

# %%
#This is the data collected from the web
df2 = pd.read_csv("Fortnite_Q.csv")

#Renaming the column headers to match previous data
df3 = df2.rename(index=str, columns={"Which quadrant did you land in? Use map below for reference": "Location", 
                                     "Which game mode were you in?": "Mode",
                                    "What place did you finish? (Example: 4)" : "Position",
                                    "How many kills did you get? (Example: 7)" : "KillCount"})

#Dropping the 'Mode' column
df4 = df3.drop(df3.columns[2], axis=1)

# %%
avg_kills2 = df4.iloc[:, 1:4].drop(df4.columns[2], axis=1)
#Average number of kills per location
group_kills = avg_kills2.groupby('Location').agg('mean')

group_kills

plot = group_kills.plot(kind = 'bar', color = 'green')

# %%
#Average position per drop location
avg_pos2 = df4.iloc[:,[1,2]]
avg_pos2

group_pos2 = avg_pos2.groupby('Location').agg('mean')
group_pos2.describe()
# Out:
#         Position
# count  35.000000
# mean    7.434014
# std    11.280066
# min     1.000000
# 25%     2.000000
# 50%     3.000000
# 75%     7.642857
# max    60.000000

# %%
plot = group_pos2.plot(kind = 'kde', color = 'red')
plot.set_xlim(0,15)
plot.set_ylim(0,.18)
# Out:
# (0, 0.18)

# %%
#Messing around with linear regression

target = df.iloc[:,2]

X = df["KillCount"]
Y = target

model = sm.OLS(Y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Position   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     4.599
# Date:                Thu, 22 Mar 2018   Prob (F-statistic):             0.0351
# Time:                        12:34:33   Log-Likelihood:                -391.37
# No. Observations:                  80   AIC:                             784.7
# Df Residuals:                      79   BIC:                             787.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# KillCount      3.2158      1.500      2.144      0.035       0.231       6.201
# ==============================================================================
# Omnibus:                        2.911   Durbin-Watson:                   0.812
# Prob(Omnibus):                  0.233   Jarque-Bera (JB):                2.325
# Skew:                           0.227   Prob(JB):                        0.313
# Kurtosis:                       3.701   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Scatter plot with online data
df_scatter = df4.iloc[:, 2:4]
x = df_scatter["Position"]
y = df_scatter["KillCount"]

plt.scatter(x,y)
plt.ylabel("KillCount")
plt.xlabel("Placement")
plt.show()
